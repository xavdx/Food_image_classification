# %%
# Notebook 00: Environment & Utilities
# Colab instructions: Runtime -> Change runtime type -> GPU
# (Optional) Runtime -> Manage sessions -> High-RAM if available.
#1) Install required libraries
# !pip install -q torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install -q timm==0.9.2 scikit-learn matplotlib seaborn pandas tqdm albumentations==1.3.0 einops
# !pip install -q grad-cam   # for GradCAM visualizations
#If colab gives issues with torch version, adapt to preinstalled torch.
#2) Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
#3) Set global paths and seed
import os, random, json
import numpy as np
import torch
ROOT_DRIVE="/content/drive/MyDrive/food-10/food-10"
IMAGES_DIR=os.path.join(ROOT_DRIVE, "images")
TRAIN_TXT=os.path.join(ROOT_DRIVE, "train.txt")
TEST_TXT=os.path.join(ROOT_DRIVE, "test.txt")
OUTPUT_DIR="/content/food10_outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
set_seed(42)
print("ROOT_DRIVE:", ROOT_DRIVE)
print("Images folder exists?", os.path.exists(IMAGES_DIR))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 55.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ROOT_DRIVE: /content/drive/MyDrive/food-10/food-10
# Images folder exists? True
